# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
alunos= pd.read_csv('alunos2014.csv', delimiter=';')

# %%
alunos.dtypes
# Out:
# inep_escola                      int64
# codigo_escola                    int64
# matricula_aluno                  int64
# data_nascimento                 object
# sexo                             int64
# raca                             int64
# uf_nascimento                   object
# codigo_municipio_nascimento      int64
# municipio_nascimento            object
# zona_residencia                float64
# codigo_bairro                  float64
# bairro                          object
# uf                              object
# codigo_municipio               float64
# municipio                       object
# deficiencia                    float64
# deficiencia_cegueira           float64
# deficiencia_baixavisao         float64
# deficiencia_surdez             float64
# deficiencia_baixaaudicao       float64
# deficiencia_surdocegueira      float64
# deficiencia_fisica             float64
# deficiencia_intelectual        float64
# deficiencia_multipla           float64
# ...

# %%
alunos['sexo'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
alunos['raca'].unique()
# Out:
# array([3, 2, 0, 1, 5, 4], dtype=int64)

# %%
alunos.head(2)
# Out:
#    inep_escola  codigo_escola  matricula_aluno data_nascimento  sexo  raca  \
# 0     26175347            384         10270132      2009-05-02     2     3
# 1     26175347            384         11372931      2010-02-23     1     3
#
#   uf_nascimento  codigo_municipio_nascimento  \
# 0            PE                      2609600
# 1            PE                      2611606
#
#                                 municipio_nascimento  zona_residencia  \
# 0  OLINDA                                        ...              1.0
# 1  RECIFE                                        ...              1.0
#
#              ...             deficiencia_baixaaudicao  \
# 0            ...                                  NaN
# 1            ...                                  NaN
#
#   deficiencia_surdocegueira deficiencia_fisica  deficiencia_intelectual  \
# 0                       NaN                NaN                      NaN
# ...

# %%
alunos.isnull().sum().head(20)
# Out:
# inep_escola                        0
# codigo_escola                      0
# matricula_aluno                    0
# data_nascimento                    0
# sexo                               0
# raca                               0
# uf_nascimento                      0
# codigo_municipio_nascimento        0
# municipio_nascimento               0
# zona_residencia                    1
# codigo_bairro                   1964
# bairro                            10
# uf                                 2
# codigo_municipio                   2
# municipio                          2
# deficiencia                        1
# deficiencia_cegueira           87791
# deficiencia_baixavisao         87791
# deficiencia_surdez             87791
# deficiencia_baixaaudicao       87791
# dtype: int64

# %%
alunos.drop(alunos[alunos.uf == "" ].index , inplace=True)

# %%
alunos.isnull().sum().head(20)
# Out:
# inep_escola                        0
# codigo_escola                      0
# matricula_aluno                    0
# data_nascimento                    0
# sexo                               0
# raca                               0
# uf_nascimento                      0
# codigo_municipio_nascimento        0
# municipio_nascimento               0
# zona_residencia                    1
# codigo_bairro                   1964
# bairro                            10
# uf                                 2
# codigo_municipio                   2
# municipio                          2
# deficiencia                        1
# deficiencia_cegueira           87791
# deficiencia_baixavisao         87791
# deficiencia_surdez             87791
# deficiencia_baixaaudicao       87791
# dtype: int64

# %%
alunos.shape
# Out:
# (91165, 29)

# %%
alunos.columns
# Out:
# Index(['inep_escola', 'codigo_escola', 'matricula_aluno', 'data_nascimento',
#        'sexo', 'raca', 'uf_nascimento', 'codigo_municipio_nascimento',
#        'municipio_nascimento', 'zona_residencia', 'codigo_bairro', 'bairro',
#        'uf', 'codigo_municipio', 'municipio', 'deficiencia',
#        'deficiencia_cegueira', 'deficiencia_baixavisao', 'deficiencia_surdez',
#        'deficiencia_baixaaudicao', 'deficiencia_surdocegueira',
#        'deficiencia_fisica', 'deficiencia_intelectual', 'deficiencia_multipla',
#        'deficiencia_autismo', 'deficiencia_asperger', 'deficiencia_rett',
#        'deficiencia_desintegrativo', 'deficiencia_superdotacao'],
#       dtype='object')

# %%
alunos.head(5)
# Out:
#    inep_escola  codigo_escola  matricula_aluno data_nascimento  sexo  raca  \
# 0     26175347            384         10270132      2009-05-02     2     3
# 1     26175347            384         11372931      2010-02-23     1     3
# 2     26175347            384         12960799      2009-04-10     2     2
# 3     26175347            384         12960845      2009-10-27     1     3
# 4     26175347            384         12960900      2010-01-31     2     3
#
#   uf_nascimento  codigo_municipio_nascimento  \
# 0            PE                      2609600
# 1            PE                      2611606
# 2            PE                      2609600
# 3            PE                      2609600
# 4            PE                      2609600
#
#                                 municipio_nascimento  zona_residencia  \
# 0  OLINDA                                        ...              1.0
# 1  RECIFE                                        ...              1.0
# ...

# %%
def a(x):
    return x['deficiencia_fisica'].sum() >200
alunos.groupby('municipio_nascimento').filter(a)
# Out:
#        inep_escola  codigo_escola  matricula_aluno data_nascimento  sexo  \
# 1         26175347            384         11372931      2010-02-23     1
# 5         26175347            384         12961060      2009-12-13     1
# 7         26175347            384         12961221      2009-08-07     1
# 8         26175347            384         12961302      2009-06-04     2
# 9         26175347            384         14000890      2009-09-08     2
# 10        26175347            384         14003252      2009-08-31     2
# 11        26175347            384         14014599      2009-11-27     1
# 12        26175347            384         14023741      2009-07-08     2
# 13        26175347            384         14025809      2009-09-21     2
# 14        26175347            384         14029308      2009-09-30     2
# 15        26175347            384         14035723      2009-04-22     1
# 17        26175347            384         14318873      2009-07-10     2
# ...

# %%
escolaEQtdDef =alunos.groupby(['municipio_nascimento', 'codigo_escola'])['deficiencia'].sum()

# %%
escolaEQtdDef.sort_values(ascending=False)
# Out:
# municipio_nascimento                                     codigo_escola
# RECIFE                                                   9                995
#                                                          4                851
#                                                          335              822
#                                                          1                743
#                                                          10               734
#                                                          51               695
#                                                          245              679
#                                                          132              660
#                                                          102              658
#                                                          49               656
#                                                          917              651
# ...

# %%
nascidosEmOlinda =alunos['municipio_nascimento'] == 'OLINDA '

# %%
nascidosEmOlinda.count()
# Out:
# 91165

# %%
alunos['raca'].value_counts()
# Out:
# 3    40587
# 0    32082
# 1    13706
# 2     4372
# 4      269
# 5      149
# Name: raca, dtype: int64

# %%
branco = 149
amarelo = 269
pardo= 40587

# %%
alunos['deficiencia_intelectual'].value_counts()
# Out:
# 1.0    2412
# 0.0     962
# Name: deficiencia_intelectual, dtype: int64

# %%
alunos['deficiencia_fisica'].value_counts()
# Out:
# 0.0    3011
# 1.0     363
# Name: deficiencia_fisica, dtype: int64

# %%
fisica = 3011
intelectual =962
deficiencia = 3374
total = 87790

# %%
#Desenhando um gráfico de barras horizontal:

#definindo variáveis

total = {"Fisica": fisica, "Intelectual": intelectual, "Deficiencia": deficiencia}

deficiencias = [i for i in total.keys()]

loop = [j for j in total.values()]

totalPos = np.arange(len(deficiencias))

azul = "blue"

verde = "green"

preto = "black"

# %%
def plota_barra_h_1():    
    plt.barh(totalPos, loop, align='center', color=azul)                 
    plt.yticks(totalPos, deficiencias)   
    plt.xlabel('Alunos')    
    plt.title('Deficiência Fisica x Intelectual')
    cidades
    plt.show()

# %%
plota_barra_h_1()

# %%
defOlinda = alunos['raca'] == 1

# %%
# Out:
# 91165

# %%
alunos['municipio_nascimento'] == 'OLINDA'.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-d12172138f09> in <module>()
# ----> 1 alunos['municipio_nascimento'] == 'OLINDA'.count()
#
# TypeError: count() takes at least 1 argument (0 given)

# %%
alunos.loc[(alunos['municipio_nascimento'] =='RECIFE') ]
# Out:
# Empty DataFrame
# Columns: [inep_escola, codigo_escola, matricula_aluno, data_nascimento, sexo, raca, uf_nascimento, codigo_municipio_nascimento, municipio_nascimento, zona_residencia, codigo_bairro, bairro, uf, codigo_municipio, municipio, deficiencia, deficiencia_cegueira, deficiencia_baixavisao, deficiencia_surdez, deficiencia_baixaaudicao, deficiencia_surdocegueira, deficiencia_fisica, deficiencia_intelectual, deficiencia_multipla, deficiencia_autismo, deficiencia_asperger, deficiencia_rett, deficiencia_desintegrativo, deficiencia_superdotacao]
# Index: []
#
# [0 rows x 29 columns]

# %%
alunos.loc[(alunos[""])]

# %%
alunos[alunos['raca'] == 1]
# Out:
#        inep_escola  codigo_escola  matricula_aluno data_nascimento  sexo  \
# 8         26175347            384         12961302      2009-06-04     2
# 11        26175347            384         14014599      2009-11-27     1
# 12        26175347            384         14023741      2009-07-08     2
# 39        26175347            384         14003848      2009-12-22     1
# 42        26175347            384         14006952      2009-12-09     2
# 51        26175347            384         14102072      2009-08-03     2
# 53        26175347            384         10242937      2008-06-20     2
# 63        26175347            384         14038242      2008-10-18     2
# 69        26175347            384         10012516      2009-04-01     2
# 70        26175347            384         10012524      2009-04-01     2
# 71        26175347            384         10012605      2009-04-26     1
# 74        26175347            384         12971880      2009-04-01     2
# ...

# %%
#homens
m = alunos[(alunos['sexo'] == 1)].shape

# %%
m
# Out:
# (46707, 29)

# %%
#mulheres
h= alunos[(alunos['sexo'] == 2)].sum()

# %%
#contando os alunos por municipio , 7 primeiros
pd.value_counts(alunos['municipio_nascimento']).head(7)
# Out:
# RECIFE                                                     74806
# OLINDA                                                      3956
# JABOATAO DOS GUARARAPES                                     3617
# PAULISTA                                                     973
# VITORIA DE SANTO ANTAO                                       684
# CAMARAGIBE                                                   629
# MORENO                                                       475
# Name: municipio_nascimento, dtype: int64

# %%
alunos.loc[(alunos['municipio_nascimento']=='RECIFE') & (alunos['deficiencia'] == 1)]
# Out:
# Empty DataFrame
# Columns: [inep_escola, codigo_escola, matricula_aluno, data_nascimento, sexo, raca, uf_nascimento, codigo_municipio_nascimento, municipio_nascimento, zona_residencia, codigo_bairro, bairro, uf, codigo_municipio, municipio, deficiencia, deficiencia_cegueira, deficiencia_baixavisao, deficiencia_surdez, deficiencia_baixaaudicao, deficiencia_surdocegueira, deficiencia_fisica, deficiencia_intelectual, deficiencia_multipla, deficiencia_autismo, deficiencia_asperger, deficiencia_rett, deficiencia_desintegrativo, deficiencia_superdotacao]
# Index: []
#
# [0 rows x 29 columns]

# %%
a
# Out:
# 1

# %%
print((alunos[(alunos['sexo'] == 1) & (alunos['deficiencia']== 1)]).shape)
print((alunos[(alunos['sexo'] == 1) & (alunos['deficiencia']== 0)]).shape)
# Out:
# (2175, 29)
# (44532, 29)

# %%
alunos.describe()
# Out:
#         inep_escola  codigo_escola  matricula_aluno          sexo  \
# count  9.116500e+04   91165.000000     9.116500e+04  91165.000000
# mean   2.614024e+07     261.413700     1.083262e+07      1.487665
# std    3.483186e+04     288.078799     7.515012e+06      0.499851
# min    2.611758e+07       1.000000     2.682000e+03      1.000000
# 25%    2.612344e+07      49.000000     8.114943e+06      1.000000
# 50%    2.612708e+07     133.000000     1.143535e+07      1.000000
# 75%    2.615356e+07     354.000000     1.314471e+07      2.000000
# max    2.649171e+07     999.000000     9.993836e+07      2.000000
#
#                raca  codigo_municipio_nascimento  zona_residencia  \
# count  91165.000000                 9.116500e+04          91164.0
# mean       1.601843                 2.618349e+06              1.0
# std        1.367917                 1.008046e+05              0.0
# min        0.000000                 1.100023e+06              1.0
# ...

# %%
44532+2175
# Out:
# 46707

# %%
alunos.groupby('deficiencia')

# %%
alunos.groupby('municipio_nascimento').aggregate({'deficiencia': [min,np.mean,max]})
# Out:
#                                                    deficiencia
#                                                            min      mean  max
# municipio_nascimento
# ABARE                                          ...         0.0  0.000000  0.0
# ABREU E LIMA                                   ...         0.0  0.014925  1.0
# ACAILANDIA                                     ...         0.0  0.000000  0.0
# ACREUNA                                        ...         0.0  0.000000  0.0
# ADAMANTINA                                     ...         1.0  1.000000  1.0
# AFOGADOS DA INGAZEIRA                          ...         0.0  0.055556  1.0
# AFRANIO                                        ...         0.0  0.000000  0.0
# AGRESTINA                                      ...         0.0  0.250000  1.0
# AGUA BRANCA                                    ...         0.0  0.000000  0.0
# AGUA PRETA                                     ...         0.0  0.000000  0.0
# ...

# %%
alunos['deficiencia_baixavisao'].value_counts()
# Out:
# 0.0    3211
# 1.0     163
# Name: deficiencia_baixavisao, dtype: int64

# %%
alunos['deficiencia_cegueira'].value_counts()
# Out:
# 0.0    3339
# 1.0      35
# Name: deficiencia_cegueira, dtype: int64

# %%
baixavisao = 163

# %%
cegueira = 35
