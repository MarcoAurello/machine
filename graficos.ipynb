# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pydataset

# %%
titanic = pydataset.data('titanic')

# %%
titanic.head()
# Out:
#        class     age  sex survived
# 1  1st class  adults  man      yes
# 2  1st class  adults  man      yes
# 3  1st class  adults  man      yes
# 4  1st class  adults  man      yes
# 5  1st class  adults  man      yes

# %%
titanic['class'].value_counts()
# Out:
# 3rd class    706
# 1st class    325
# 2nd class    285
# Name: class, dtype: int64

# %%
#distribuição de frequencias
titanic['class'].value_counts().plot(kind='bar')

# %%
titanic['survived'].value_counts().plot(kind='bar')

# %%
titanic.groupby('survived')['class'].value_counts()
# Out:
# survived  class
# no        3rd class    528
#           2nd class    167
#           1st class    122
# yes       1st class    203
#           3rd class    178
#           2nd class    118
# Name: class, dtype: int64

# %%
titanic.groupby('survived')['class'].value_counts().plot(kind='bar')

# %%
df = pd.read_csv('populacao_brasil.csv')

# %%
df.dtypes
# Out:
# estado    object
# total      int64
# dtype: object

# %%
df['total'].hist()

# %%
fig, ax = plt.subplots()
plt.hist(estados['total'],bins=15, orientation='horizontal')
ax.ticklebal_format(style = 'plan')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-82eabba85b57> in <module>()
#       1 fig, ax = plt.subplots()
# ----> 2 plt.hist(estados['total'],bins=15, orientation='horizontal')
#       3 ax.ticklebal_format(style = 'plan')
#       4 plt.show()
#
# NameError: name 'estados' is not defined

# %%
df['percent'] = df['total'] / df['total'].sum()

# %%
df.head()
# Out:
#   estado     total   percent
# 0     SP  44846530  0.217418
# 1     MG  21024678  0.101929
# 2     RJ  16690709  0.080917
# 3     BA  15276566  0.074062
# 4     RS  11286500  0.054718

# %%
plt.pie(df['percent'],labels= df['estado'])
plt.show()

# %%
plt.pie(df['percent'],labels= df['estado'], autopct='%1.2f%%')
plt.show()

# %%
 dsAer =titanic = pydataset.data('AirPassengers')

# %%
dsAer.head(12)
# Out:
#            time  AirPassengers
# 1   1949.000000            112
# 2   1949.083333            118
# 3   1949.166667            132
# 4   1949.250000            129
# 5   1949.333333            121
# 6   1949.416667            135
# 7   1949.500000            148
# 8   1949.583333            148
# 9   1949.666667            136
# 10  1949.750000            119
# 11  1949.833333            104
# 12  1949.916667            118

# %%
plt.plot(dsAer['time'], dsAer['AirPassengers'])

# %%
plt.scatter(dsAer['time'], dsAer['AirPassengers'])

# %%
iris = pydataset.data('iris')

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
plt.scatter(iris['Sepal.Length'],iris['Sepal.Width'] ,sizes= 20*iris['Petal.Length'])

# %%
def especie(x):
    if x == 'setosa':
        return 0
    elif x =='versicolor':
        return 1
    return 2

# %%
iris['especieNumero'] = iris['Species'].apply(especie)

# %%
plt.scatter(iris['Sepal.Length'],iris['Sepal.Width'] ,sizes= 20*iris['Petal.Length'],c=iris['especieNumero'],
            cmap='viridis', alpha=0.4)

# %%
d

# %%
df['total'].sum
# Out:
# <bound method Series.sum of 0     44846530
# 1     21024678
# 2     16690709
# 3     15276566
# 4     11286500
# 5     11242720
# 6      9410336
# 7      8980879
# 8      8272724
# 9      6954036
# 10     6910553
# 11     6695855
# 12     4001667
# 13     3999415
# 14     3973697
# 15     3474998
# 16     3358963
# 17     3305531
# 18     3212180
# 19     2977216
# 20     2682386
# 21     2265779
# 22     1787279
# 23     1523902
# 24      816687
# 25      782295
# 26      514229
# Name: total, dtype: int64>
