# %%
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt

# %%
df = pd.read_csv('CoeficienteMortalidadeInfantil_dado.csv', delimiter=';' )

# %%
df.isnull().sum()
# Out:
# Municípios                                                      0
# Coeficiente de mortalidade infantil (por mil nascidos vivos)    0
# Nascidos vivos                                                  0
# Óbito infantil                                                  0
# dtype: int64

# %%
df[df['Óbito infantil']=="-"]
# Out:
# C:\Users\marco\Anaconda3\lib\site-packages\pandas\core\ops.py:798: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-daa4f8edea89> in <module>()
# ----> 1 df[df['Óbito infantil']=="-"]
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     798                     result = getattr(x, name)(y)
#     799                 if result is NotImplemented:
# ...

# %%
df.head()
# Out:
#               Municípios  \
# 0           Abreu e Lima
# 1  Afogados da Ingazeira
# 2                Afrânio
# 3              Agrestina
# 4             Água Preta
#
#   Coeficiente de mortalidade infantil (por mil nascidos vivos)  \
# 0                                              14,12
# 1                                              24,43
# 2                                               6,41
# 3                                              17,18
# 4                                              18,65
#
#    Nascidos vivos  Óbito infantil
# 0            1346              19
# 1             573              14
# 2             312               2
# 3             291               5
# 4             429               8

# %%
df.isnull.sum

# %%
a= df

# %%
df.dtypes
# Out:
# Municípios                                                      object
# Coeficiente de mortalidade infantil (por mil nascidos vivos)    object
# Nascidos vivos                                                   int64
# Óbito infantil                                                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Municípios                                                      0
# Coeficiente de mortalidade infantil (por mil nascidos vivos)    0
# Nascidos vivos                                                  0
# Óbito infantil                                                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Municípios',
#        'Coeficiente de mortalidade infantil (por mil nascidos vivos)',
#        'Nascidos vivos', 'Óbito infantil'],
#       dtype='object')

# %%
print('Qantas municipios tem o arquivo: ',len(df))
# Out:
# Qantas municipios tem o arquivo:  185

# %%
#lista os 5 primeiros
df.head()
# Out:
#               Municípios  \
# 0           Abreu e Lima
# 1  Afogados da Ingazeira
# 2                Afrânio
# 3              Agrestina
# 4             Água Preta
#
#   Coeficiente de mortalidade infantil (por mil nascidos vivos)  \
# 0                                              14,12
# 1                                              24,43
# 2                                               6,41
# 3                                              17,18
# 4                                              18,65
#
#    Nascidos vivos Óbito infantil
# 0            1346             19
# 1             573             14
# 2             312              2
# 3             291              5
# 4             429              8

# %%
municipiosNascidosVivos =df.groupby(['Municípios'])['Nascidos vivos']

# %%
municipiosNascidosVivos

# %%
df2 = df.sort_values(['Óbito infantil'], ascending=False)

# %%
df2.dtypes
# Out:
# Municípios                                                      object
# Coeficiente de mortalidade infantil (por mil nascidos vivos)    object
# Nascidos vivos                                                   int64
# Óbito infantil                                                   int64
# dtype: object

# %%
df2
# Out:
#                    Municípios  \
# 131                    Recife
# 87    Jaboatão dos Guararapes
# 125                 Petrolina
# 110                    Olinda
# 44                    Caruaru
# 121                  Paulista
# 30    Cabo de Santo Agostinho
# 12                  Araripina
# 66                  Garanhuns
# 36                 Camaragibe
# 142  Santa Cruz do Capibaribe
# 183    Vitória de Santo Antão
# 78                    Ipojuca
# 29                     Buíque
# 113                  Ouricuri
# 18                Belo Jardim
# 5                 Águas Belas
# 157             Serra Talhada
# 79                      Ipubi
# 0                Abreu e Lima
# 174                  Trindade
# 155      São Lourenço da Mata
# 74                   Igarassu
# 144  Santa Maria da Boa Vista
# 123                 Pesqueira
# 68                     Goiana
# 137                 Salgueiro
# 13                  Arcoverde
# 43                    Carpina
# 55                   Custódia
# ...

# %%
a= df['Coeficiente de mortalidade infantil (por mil nascidos vivos)'].sort_values(ascending=True)

# %%
df['Óbito infantil'].sort_values(ascending=False)
# Out:
# 131    287
# 87     109
# 125     89
# 110     80
# 44      75
# 121     58
# 30      49
# 12      43
# 66      37
# 36      33
# 142     30
# 183     26
# 78      23
# 29      22
# 113     22
# 18      22
# 5       21
# 157     20
# 79      20
# 0       19
# 174     19
# 74      18
# 144     18
# 155     18
# 137     17
# 68      17
# 123     17
# 13      16
# 43      15
# 114     14
#       ...
# 173      2
# 64       2
# 47       2
# 80       2
# 69       2
# 75       2
# 52       2
# 48       2
# 138      2
# 45       2
# 93       2
# 88       2
# 89       2
# 162      2
# 34       2
# 136      1
# 60       1
# 115      1
# 98       1
# 53       1
# 128      1
# 10       1
# 111      1
# 35       1
# 61       1
# 129      1
# 16       1
# 77       0
# 117      0
# 28       0
# Name: Óbito infantil, Length: 185, dtype: int64

# %%
df = pd.DataFrame(a, columns=['municipios','coeficiente de mortalidade','nascidos vivos','obto infantil'])

# %%
df2 = df.sort_values(['Óbito infantil'],ascending=False)

# %%
df.dtypes
# Out:
# Municípios                                                      object
# Coeficiente de mortalidade infantil (por mil nascidos vivos)    object
# Nascidos vivos                                                   int64
# Óbito infantil                                                  object
# dtype: object

# %%
df['Coeficiente de mortalidade infantil (por mil nascidos vivos)'] = df['Coeficiente de mortalidade infantil (por mil nascidos vivos)'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-8367a60a7742> in <module>()
# ----> 1 df['Coeficiente de mortalidade infantil (por mil nascidos vivos)'] = df['Coeficiente de mortalidade infantil (por mil nascidos vivos)'].astype(float)
#
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
# ...

# %%
df[28]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2521             try:
# -> 2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 28
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
alunos.loc[(alunos['municipio_nascimento'] =='RECIFE') ]

# %%
df.loc[(df['Óbito infantil'] == '-') ]
# Out:
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\pandas\core\ops.py:816: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-45955d42a8ca> in <module>()
# ----> 1 df.loc[(df['Óbito infantil'] == '-') ]
#
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     877
#     878             with np.errstate(all='ignore'):
# --> 879                 res = na_op(values, other)
#     880             if is_scalar(res):
#     881                 raise TypeError('Could not compare {typ} type with Series'
#
# ...

# %%
df2
# Out:
#                     Municípios  \
# 122                      Pedra
# 153       São José do Belmonte
# 17      Belém do São Francisco
# 178                  Venturosa
# 116                    Panelas
# 125                  Petrolina
# 110                     Olinda
# 184                      Xexéu
# 112                      Orocó
# 105                     Manari
# 4                   Água Preta
# 62                      Flores
# 44                     Caruaru
# 145     Santa Maria do Cambucá
# 119                    Passira
# 141  Santa Cruz da Baixa Verde
# 7                      Aliança
# 83                      Itambé
# 133                   Ribeirão
# 159                   Sertânia
# 24                      Bonito
# 27      Brejo da Madre de Deus
# 40                   Capoeiras
# 108                     Moreno
# 59                  Feira Nova
# 148           São Bento do Una
# 154          São José do Egito
# 134                Rio Formoso
# 91                João Alfredo
# ...

# %%
df
# Out:
#                  Municípios  \
# 0              Abreu e Lima
# 1     Afogados da Ingazeira
# 2                   Afrânio
# 3                 Agrestina
# 4                Água Preta
# 5               Águas Belas
# 6                 Alagoinha
# 7                   Aliança
# 8                   Altinho
# 9                   Amaraji
# 10                  Angelim
# 11                Araçoiaba
# 12                Araripina
# 13                Arcoverde
# 14       Barra de Guabiraba
# 15                Barreiros
# 16           Belém de Maria
# 17   Belém do São Francisco
# 18              Belo Jardim
# 19                  Betânia
# 20                 Bezerros
# 21                   Bodocó
# 22             Bom Conselho
# 23               Bom Jardim
# 24                   Bonito
# 25                   Brejão
# 26                 Brejinho
# 27   Brejo da Madre de Deus
# 28             Buenos Aires
# 29                   Buíque
# ..                      ...
# 155    São Lourenço da Mata
# ...

# %%
df
# Out:
#                  Municípios  \
# 0              Abreu e Lima
# 1     Afogados da Ingazeira
# 2                   Afrânio
# 3                 Agrestina
# 4                Água Preta
# 5               Águas Belas
# 6                 Alagoinha
# 7                   Aliança
# 8                   Altinho
# 9                   Amaraji
# 10                  Angelim
# 11                Araçoiaba
# 12                Araripina
# 13                Arcoverde
# 14       Barra de Guabiraba
# 15                Barreiros
# 16           Belém de Maria
# 17   Belém do São Francisco
# 18              Belo Jardim
# 19                  Betânia
# 20                 Bezerros
# 21                   Bodocó
# 22             Bom Conselho
# 23               Bom Jardim
# 24                   Bonito
# 25                   Brejão
# 26                 Brejinho
# 27   Brejo da Madre de Deus
# 28             Buenos Aires
# 29                   Buíque
# ..                      ...
# 155    São Lourenço da Mata
# ...

# %%
df2
# Out:
#                   Municípios  \
# 117               Paranatama
# 77                 Ingazeira
# 28              Buenos Aires
# 57                    Escada
# 118               Parnamirim
# 136               Salgadinho
# 35                   Calumbi
# 168    Taquaritinga do Norte
# 48            Chã de Alegria
# 47                     Cedro
# 52                    Cortês
# 167                Tamandaré
# 93                    Jucati
# 151     São Joaquim do Monte
# 24                    Bonito
# 75                  Iguaracy
# 54                    Cupira
# 83                    Itambé
# 140               Santa Cruz
# 64           Frei Miguelinho
# 133                 Ribeirão
# 7                    Aliança
# 179               Verdejante
# 87   Jaboatão dos Guararapes
# 155     São Lourenço da Mata
# 85                Itapissuma
# 51                 Correntes
# 139                  Sanharó
# 11                 Araçoiaba
# 120                 Paudalho
# ..                       ...
# ...

# %%
df['Nascidos vivos'].sort_values(ascending=False)
# Out:
# 131    21742
# 87      8870
# 110     5975
# 125     5353
# 44      5126
# 121     3624
# 30      3299
# 66      2409
# 36      2171
# 183     1975
# 12      1690
# 78      1464
# 155     1460
# 74      1378
# 0       1346
# 157     1331
# 18      1175
# 68      1141
# 123     1104
# 70      1101
# 137     1080
# 13      1073
# 29      1064
# 142     1047
# 43      1042
# 113     1026
# 57       998
# 163      897
# 114      884
# 120      849
#        ...
# 61       181
# 128      178
# 25       173
# 75       171
# 64       167
# 179      164
# 146      157
# 34       152
# 170      150
# 88       150
# 161      146
# 16       143
# 10       142
# 135      136
# 115      135
# 180      132
# 147      127
# 177      126
# 38       111
# 169      110
# 26       103
# 73       102
# 69       102
# 162      100
# 136       96
# 35        96
# 80        89
# 130       88
# 77        61
# 60        23
# Name: Nascidos vivos, Length: 185, dtype: int64

# %%
municipiosNascidosVivos

# %%
print(municipiosNascidosVivos)

# %%
Ocorrenciacarnaval
# Out:
# Município                 Agropecuária
# Abreu e Lima              26              1
# Afogados da Ingazeira     13              1
# Afrânio                   15              1
# Agrestina                 143             1
# Alagoinha                 2               1
# Aliança                   1464            1
# Altinho                   27              1
# Amaraji                   103             1
# Angelim                   34              1
# Araripina                 14              1
# Araçoiaba                 3               1
# Arcoverde                 93              1
# Barra de Guabiraba        3539            1
# Barreiros                 593             1
# Belo Jardim               206             1
# Belém de Maria            4               1
# Belém do São Francisco    668             1
# Betânia                   2               1
# Bezerros                  187             1
# Bodocó                    -               1
# ...
